# %%
import pandas as pd

# %%
df = pd.read_csv("sales_and_customer_insights (1).csv")
df.head()
# Out:
#    Customer_ID   Product_ID Transaction_ID  Purchase_Frequency  \
# 0  CUST_9HOS83  PROD_IK97D1   TRANS_II1DZG                  17
# 1  CUST_AJU17N  PROD_UNN7KP   TRANS_9HJF7I                  10
# 2  CUST_11XNYF  PROD_0XEW2W   TRANS_OT96OM                   3
# 3  CUST_IGH8G3  PROD_3IIAJN   TRANS_45V00G                  12
# 4  CUST_OK6PUM  PROD_VMIWD2   TRANS_ZAK760                  18
#
#    Average_Order_Value Most_Frequent_Category  Time_Between_Purchases  \
# 0               172.57            Electronics                      45
# 1                64.89               Clothing                       6
# 2               120.38                 Sports                      23
# 3                70.34               Clothing                       5
# 4                42.39            Electronics                      10
#
#           Region  Churn_Probability  Lifetime_Value Launch_Date  \
# 0  South America               0.98          952.81  2020-03-14
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID                 0
# Product_ID                  0
# Transaction_ID              0
# Purchase_Frequency          0
# Average_Order_Value         0
# Most_Frequent_Category      0
# Time_Between_Purchases      0
# Region                      0
# Churn_Probability           0
# Lifetime_Value              0
# Launch_Date                 0
# Peak_Sales_Date             0
# Season                      0
# Preferred_Purchase_Times    0
# Retention_Strategy          0
# dtype: int64

# %%
df.dropna()
# Out:
#       Customer_ID   Product_ID Transaction_ID  Purchase_Frequency  \
# 0     CUST_9HOS83  PROD_IK97D1   TRANS_II1DZG                  17
# 1     CUST_AJU17N  PROD_UNN7KP   TRANS_9HJF7I                  10
# 2     CUST_11XNYF  PROD_0XEW2W   TRANS_OT96OM                   3
# 3     CUST_IGH8G3  PROD_3IIAJN   TRANS_45V00G                  12
# 4     CUST_OK6PUM  PROD_VMIWD2   TRANS_ZAK760                  18
# ...           ...          ...            ...                 ...
# 9995  CUST_BIH0QW  PROD_AAPCHD   TRANS_EP2EGL                  15
# 9996  CUST_DWJAD2  PROD_XWJQE5   TRANS_X7OPB7                  18
# 9997  CUST_43HBYL  PROD_PL3BU5   TRANS_VSZM3Y                  15
# 9998  CUST_0SX4MD  PROD_X5O49V   TRANS_B2YCHY                  12
# 9999  CUST_U1AP5I  PROD_CTS1GQ   TRANS_IBPVC5                   3
#
#       Average_Order_Value Most_Frequent_Category  Time_Between_Purchases  \
# 0                  172.57            Electronics                      45
# ...

# %%
df['Launch_Date'] =pd.to_datetime(df['Launch_Date'])
df['Peak_Sales_Date'] =pd.to_datetime(df['Peak_Sales_Date'])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['Purchase_Frequency','Average_Order_Value','Lifetime_Value']] = scaler.fit_transform(
df[['Purchase_Frequency','Average_Order_Value','Lifetime_Value']]
)

# %%
df.to_csv("cleaned_sales_data.csv",index=False)
print("Cleaned data save succesfully")
# Out:
# Cleaned data save succesfully

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Region',data=df)
plt.title("Customer Distribution by region")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Average_Order_Value'],bins=20,kde=True)
plt.title(" Distribution of Average order value ")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Most_Frequent_Category',y='Lifetime_Value',data=df)
plt.title("Customer Lifetime value by product category")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Purchase_Frequency',y='Lifetime_Value',data=df)
plt.title("Purchase Frequency value by product category")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Retention_Strategy',data=df)
plt.title("Retention_Strategy")
plt.show()
